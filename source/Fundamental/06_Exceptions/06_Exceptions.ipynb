# %% [markdown]
# # Chapter 6: Files and Exceptions

# %% [markdown]
# ## Topics
# 1. Introduction to File Input and Output
# 2. Using Loops to Process Files
# 3. Processing Records
# 4. Exceptions

# %% [markdown]
# ## 1. Opening, reading, and writing files (Follow):
#
# **Learning Objectives:**
#
#     1. Understand how to open and close files.
#     2. Understand how to write to and read from files.

# %% [markdown]
# ### 1.1. Introduction to File Input and Output
# - Programs often need to save data to files and retrieve data from files.
# - This process involves writing data to output files and reading data from input files.
# - Three steps when a program uses a file: Open, Process, Close.

# %%
# Example of writing to a file
file = open('data/example.txt', 'w')
file.write('Hello, World!')
file.close()

# %%
# Example of reading from a file
file = open('data/example.txt', 'r')
content = file.read()
print(content)
file.close()
# Out:
# Hello, World!

# %%
# add comments to the code
# file read/write flags
# 'r' read
# 'r+' read/write
# 'w' write
# 'w+' write/read
# 'a' append
# 'a+' append/read

def main():
    array = []
    infile = open('data/test.txt', 'r')
    element = infile.readline()
    counter = 1

    while element != '' and counter <= 5:
        element = element.rstrip('\n')
        array.append([char for char in element])
        element = infile.readline()
        counter += 1

    infile.close()


    for item in array:
        print(item, end=' ')


if __name__ == '__main__':
    main()
# Out:
# ['4', '2', '3'] ['1', '6', '9'] ['7', '3']

# %%
def main():
    infile = open('data/test.txt', 'r')
    lines = infile.readlines()
    for element in lines:
        print(element)

    infile.close()


if __name__ == '__main__':
    main()
# Out:
# ['423\n', '169\n', '73\n', '359\n', '9\n', '3\n', '21\n', '199\n', '490\n', '342\n', '200\n', '238\n', '190\n', '43\n', '222\n', '169\n', '5\n', '458\n', '382\n', '244\n', '\n', '\n', '314\n', '121\n', '276\n', '233\n', '312\n', '170\n', '282\n', '94\n', '352\n', '108\n', '211\n', '225\n', '\n', '50\n', '192\n', '430\n', '76\n', '291\n', '335\n', '319\n', '106\n', '269\n', '91\n', '343\n', '42\n', '\n', '326\n', '432\n', '\n', '499\n', '304\n', '151\n', '122\n', '340\n', '177\n', '412\n', '124\n', '197\n', '118\n']

# %%
# add comments to the code
import random

def main():
    filename = "data/test.txt"

    numberOfRandoms = int(input('Enter the number of random numbers '
                                'to be written to the file: '))
    outputFile = open(filename, 'a')
    outputFile.write('\n')

    for counter in range(numberOfRandoms):
        randomNumber = random.randint(1, 500)
        outputFile.write(str(randomNumber) + '\n')

    outputFile.close()


if __name__ == '__main__':
    main()

# %% [markdown]
# ### As the above code executes, think about the following questions:
#
# 1. In the first code example, why are only five lines printed?
# 2. In the first code example, what does the line infile.readline() do?
# 3. In the first code sample, what does the line.rstrip() function do?
# 4. In the second code sample, what does the infile.readlines() function do?
# 5. Why is there space between each output in the second code sample?
# 6. What does the infile.close() function do?

# %% [markdown]
# ## 1.2 Opening, reading, and writing files (Group):
#
# **Write a program that will do the following:**
#
#     1. Read the data/test.txt file to your program.
#     2. Remove all whitespace and carriage returns from the file.
#     3. Count the number of lines in the file and print the altered contents to the console.
#
#     For example:  the first line should output "oneline"
#     Hint: Use the replace function to accomplish this.

# %%
def main():
    infile = open('data/test.txt', 'r+') # Open the file for reading and writing
    lines = infile.readlines()

    for element in lines:
        element = element.strip("\n")
        element = element.replace(" ", "")
        print(element, end="")

    infile.close()


if __name__ == '__main__':
    main()
# Out:
# 423169733599321199490342200238190432221695458382244

# %% [markdown]
# ## Types of Files and File Access Methods
# - **Text Files**: Contain data that has been encoded as text.
# - **Binary Files**: Contain data that has not been converted to text.
# - **Sequential Access**: File is read sequentially from beginning to end.
# - **Direct Access**: Can jump directly to any piece of data in the file.

# %%
# Example of appending to a file
file = open('data/example.txt', 'a')
file.write('\nAppend this line.')
file.close()

# Reading the appended file
file = open('data/example.txt', 'r')
content = file.read()
print(content)
file.close()
# Out:
# Hello, World!
# Append this line.

# %% [markdown]
# ## 2.1  File structure, file formats, and non-standard file encoding (Follow):
#
# **Learning Objectives:**
#
#     1. Understand how to deal with standard text files.
#     2. Understand how to deal with CSV files.
#     3. Understand how to deal with non-standard encoded files.
#     4. Understand how to use with open and mode

# %%
import csv

with open('output/grades.csv', mode='w', newline='') as grades:
    writer = csv.writer(grades)
    writer.writerow([1, 'Red', 'A'])
    writer.writerow([2, 'Green', 'B'])
    writer.writerow([3, 'Blue', 'C'])
    writer.writerow([4, 'Purple', 'D'])
    writer.writerow([5, 'Orange', 'Excellent'])

with open('output/grades.csv', 'r', newline='') as grades:
    print(f'{"ID":<4}{"Name":<7}{"Grade"}')
    reader = csv.reader(grades)
    for record in reader:
        student_id, name, grade = record
        print(f'{student_id:<4}{name:<7}{grade}')
# Out:
# ID  Name   Grade
# 1   Red    A
# 2   Green  B
# 3   Blue   C
# 4   Purple D
# 5   Orange Excellent

# %%
# This file associate with data/test and data/test-binary

# https://docs.python.org/3/library/io.html
# The above link is the documentation for the builtin io class in python
# add comments to the code

def main():
    infile = open('data/test.txt', 'r')

    lines = infile.readlines()

    outfile = open('output/test-binary.bin', 'w')
    for line in lines:
        for character in line:
            binary_character = format(ord(character), '08b')
            outfile.write(binary_character)
        outfile.write('\n')  # Write each binary character on a new line

    outfile.close()
    infile.close()


if __name__ == '__main__':
    main()

# %% [markdown]
# ## Exceptions
# - Exceptions are errors that occur during the execution of a program.
# - They can be handled using `try` and `except` statements to prevent the program from crashing.

# %%
# Example of handling exceptions
try:
    value = int(input('Enter a number: '))
    print('You entered:', value)
except ValueError:
    print('That is not a valid number.')
# Out:
# That is not a valid number.

# %% [markdown]
# ## 2.2  File structure, file formats, and non-standard file encoding (Group):
#
# **Write a program that will do the following:**
#
#     1. Create a new CSV file with 4 columns.
#     2. The columns should be ID, Name, Grade, and raw score.
#     3. The ID, name, and grade can be anything you want.
#     4. The raw score column should be a random number between 0 and 100.
#     5. Write the results to the file.
#     6. Next, read the file and find the average grade for all students.
#     7. The CSV should have at least 5 rows.
#     8. As an added challenge, try changing the Grade to match the raw score.

# %%
import random
import csv

average = 0
count = 0

with open('data/grades2.csv', mode='w', newline='') as grades:
    writer = csv.writer(grades)
    writer.writerow([1, 'Red', 'A', random.randint(0, 100)])
    writer.writerow([2, 'Green', 'B', random.randint(0, 100)])
    writer.writerow([3, 'Blue', 'C', random.randint(0, 100)])
    writer.writerow([4, 'Purple', 'D', random.randint(0, 100)])
    writer.writerow([5, 'Orange', 'Excellent', random.randint(0, 100)])
    # Do the same for row 2,3,4,5

with open('data/grades2.csv', 'r', newline='') as grades:
    print(f'{"ID":<4}{"Name":<7}{"Grade":<10}{"Raw Score"}')
    count = 0
    raw_score = 0
    reader = csv.reader(grades)
    for record in reader:
        student_id, name, grade, score = record
        raw_score += int(score)
        count += 1
        print(f'{student_id:<4}{name:<7}{grade:<10}{raw_score}')

    print("Average = ", raw_score / count)
# Out:
# ID  Name   Grade     Raw Score
# 1   Red    A         13
# 2   Green  B         102
# 3   Blue   C         135
# 4   Purple D         188
# 5   Orange Excellent 269
# Average =  53.8

# %% [markdown]
# ## Using Loops to Process Files
# - Loops can be used to read from and write to files, especially when dealing with large amounts of data.

# %%
# Example of using a loop to read lines from a file
file = open('data/example.txt', 'r')
for line in file:
    print(line.strip())
file.close()
# Out:
# Hello, World!
# Append this line.

# %% [markdown]
# ## 2.4  Reading in files as classes (Follow):
#
# **Learning Objectives:**
#
#     1. Understand how to read a file in as a class.
#     2. Understand why reading a file as a class can be useful.

# %%
# add comments to the code


class Athlete:
    def __init__(self, name, sex, age, height, weight, team, noc, games, year, season, city, sport, event, medal):
        self.__name = name
        self.__sex = sex
        self.__age = age
        self.__height = height
        self.__weight = weight
        self.__team = team
        self.__noc = noc
        self.__games = games
        self.__year = year
        self.__season = season
        self.__city = city
        self.__sport = sport
        self.__event = event
        self.__medal = medal

    def get_age(self):
        try:
            if int(self.__age) > 0:
                return int(self.__age)
        except ValueError:
            pass
            return 0
        except TypeError:
            print("That is not a valid age.")

# %%
import csv

athlete_list = []
age_total = 0

with open('data/athlete_events_short.csv', 'r', newline='') as athletes:
    reader = csv.reader(athletes)
    header = next(reader)
    for line in reader:
        new_athlete = Athlete(line[1], line[2], line[3], line[4], line[5], line[6],
                              line[7], line[8], line[9], line[10], line[11], line[12], line[13], line[14])
        athlete_list.append(new_athlete)

for athlete in athlete_list:
    print(f"{athlete._Athlete__name}, {athlete._Athlete__age}")
    age_total += athlete.get_age()

print(" Average age in years for all olympians = ", age_total / len(athlete_list))
# Out:
# A Dijiang, 24
# A Lamusi, 23
# Gunnar Nielsen Aaby, 24
# Edgar Lindenau Aabye, 34
# Christine Jacoba Aaftink, 21
# Christine Jacoba Aaftink, 21
# Christine Jacoba Aaftink, 25
# Christine Jacoba Aaftink, 25
# Christine Jacoba Aaftink, 27
# Christine Jacoba Aaftink, 27
# Per Knut Aaland, 31
# Per Knut Aaland, 31
# Per Knut Aaland, 31
# Per Knut Aaland, 31
# Per Knut Aaland, 33
# Per Knut Aaland, 33
# Per Knut Aaland, 33
# Per Knut Aaland, 33
# John Aalberg, 31
# John Aalberg, 31
# John Aalberg, 31
# John Aalberg, 31
# John Aalberg, 33
# John Aalberg, 33
# John Aalberg, 33
# John Aalberg, 33
# Cornelia "Cor" Aalten (-Strannood), 18
# Cornelia "Cor" Aalten (-Strannood), 18
# Antti Sami Aalto, 26
# Einar Ferdinand "Einari" Aalto, 26
# Jorma Ilmari Aalto, 22
# Jyri Tapani Aalto, 31
# Minna Maarit Aalto, 30
# Minna Maarit Aalto, 34
# Pirjo Hannele Aalto (Mattila-), 32
# Arvo Ossian Aaltonen, 22
# Arvo Ossian Aaltonen, 22
# Arvo Ossian Aaltonen, 30
# Arvo Ossian Aaltonen, 30
# Arvo Ossian Aaltonen, 34
# Juhamatti Tapio Aaltonen, 28
# Paavo Johannes Aaltonen, 28
# Paavo Johannes Aaltonen, 28
# Paavo Johannes Aaltonen, 28
# Paavo Johannes Aaltonen, 28
# Paavo Johannes Aaltonen, 28
# Paavo Johannes Aaltonen, 28
# Paavo Johannes Aaltonen, 28
# Paavo Johannes Aaltonen, 28
# Paavo Johannes Aaltonen, 32
# Paavo Johannes Aaltonen, 32
# Paavo Johannes Aaltonen, 32
# Paavo Johannes Aaltonen, 32
# Paavo Johannes Aaltonen, 32
# Paavo Johannes Aaltonen, 32
# Paavo Johannes Aaltonen, 32
# Paavo Johannes Aaltonen, 32
# Timo Antero Aaltonen, 31
# Win Valdemar Aaltonen, 54
# Kjetil Andr Aamodt, 20
# Kjetil Andr Aamodt, 20
# Kjetil Andr Aamodt, 20
# Kjetil Andr Aamodt, 20
# Kjetil Andr Aamodt, 22
# Kjetil Andr Aamodt, 22
# Kjetil Andr Aamodt, 22
# Kjetil Andr Aamodt, 22
# Kjetil Andr Aamodt, 22
# Kjetil Andr Aamodt, 26
# Kjetil Andr Aamodt, 26
# Kjetil Andr Aamodt, 26
# Kjetil Andr Aamodt, 26
# Kjetil Andr Aamodt, 30
# Kjetil Andr Aamodt, 30
# Kjetil Andr Aamodt, 30
# Kjetil Andr Aamodt, 30
# Kjetil Andr Aamodt, 30
# Kjetil Andr Aamodt, 34
# Kjetil Andr Aamodt, 34
# Ragnhild Margrethe Aamodt, 27
# Andreea Aanei, 22
# Fritz Aanes, 22
# Fritz Aanes, 26
# Nils Egil Aaness, 24
# Nils Egil Aaness, 24
# Nils Egil Aaness, 27
# Alf Lied Aanning, 24
# Agnes Erika Aanonsen (-Eyde), 17
# Johan Aantjes, 26
# Jan-Erik Aarberg, 43
# Jan-Erik Aarberg, 47
# Willemien Aardenburg, 22
# Pepijn Aardewijn, 26
# Pepijn Aardewijn, 30
# Evald rma (rman-), 24
# Olav Augunson Aarnes, 23
# Mika Lauri Aarnikka, 24
# Mika Lauri Aarnikka, 28
# Jamale (Djamel-) Aarrass (Ahrass-), 30
# Dagfinn Sverre Aarskog, 24
# Stefan Remco Aartsen, 21
# Stefan Remco Aartsen, 21
# Stefan Remco Aartsen, 21
# Stefan Remco Aartsen, 25
# Stefan Remco Aartsen, 25
# Ann Kristin Aarnes, 23
# Karl Jan Aas, 20
# Lars Thorlaksn Aas, 33
# Lars Thorlaksn Aas, 33
# Lars Thorlaksn Aas, 33
# Roald Edgar Aas, 23
# Roald Edgar Aas, 27
# Roald Edgar Aas, 27
# Roald Edgar Aas, 31
# Roald Edgar Aas, 31
# Roald Edgar Aas, 31
# Rolf Aas, 28
# Thomas Valentin Aas, 25
# Morten Gjerdrum Aasen, 34
# Meelis Aasme, 25
# Meelis Aasme, 25
# Meelis Aasme, 29
# Meelis Aasme, 29
# Meelis Aasme, 29
# Hakon Aasns, 41
# Hans Aasns, 33
# Hans Aasns, 45
# Hans Aasns, 49
# Hans Aasns, 53
# Hans Aasns, 57
# Erling Rudolf Aastad, 22
# Erling Rudolf Aastad, 22
# Erling Rudolf Aastad, 26
# Erling Rudolf Aastad, 30
# Abdelhak Aatakni, 24
# Moonika Aava, 24
# Moonika Aava, 28
# Arvi Aavik, 22
# Arvi Aavik, 26
# Nstor Abad Sanjun, 23
# Nstor Abad Sanjun, 23
# Nstor Abad Sanjun, 23
# Nstor Abad Sanjun, 23
# Nstor Abad Sanjun, 23
# Nstor Abad Sanjun, 23
# Patrick Abada, 22
# Talaat Abada, 24
# Mohamed Jamshid Abadi, NA
# Antonio Abadia Beci, 26
# Ren Abadie, 21
# Ren Abadie, 21
# Borislav Abadzhiev, 24
# Georgi Abadzhiev, NA
# Georgi Abadzhiev, NA
# Ivan Nikolov Abadzhiev, 24
# Ivan Nikolov Abadzhiev, 28
# Mikhail Abadzhiev, 24
# Stefan Abadzhiev, 26
# Giovanni Abagnale, 21
# Jos Luis Abajo Gmez, 30
# M'Bairo Abakar, 31
# Patimat Abakarova, 21
# Mohamed Abakkar, NA
# Mariya Vasilyevna Abakumova (-Tarabina), 22
# Mariya Vasilyevna Abakumova (-Tarabina), 26
# Pablo Martn Abal, 23
# Pablo Martn Abal, 23
# Tamara Abalde Daz, 19
# Jess Iory Aball Martnez, 26
# Juan Antonio Aball Delgado, 27
# Juan Antonio Aball Delgado, 27
# Aleksey Aleksandrovich Abalmasov, 24
# Aleksey Aleksandrovich Abalmasov, 28
# Luc Abalo, 23
# Luc Abalo, 27
# Luc Abalo, 31
# Mara Laura Abalo, 30
# Giorgos Abalof, 22
# Jouan Patrice Abanda Etong, 22
# Antoine Abang, 27
# Salim Abanoz, 26
# Carlos Abarca Gonzlez, 23
# Jos Mara Abarca Plotas, 22
# Georgios Abaris, 22
# Enrique Abaroa Martnez, 26
# Carlos Arturo Abarza Chavez, 22
# Stephen Anthony Abas, 26
# Alejandro Abascal Garca, 24
# Alejandro Abascal Garca, 28
# Alejandro Abascal Garca, 32
# Jos Manuel Abascal Gmez, 22
# Jos Manuel Abascal Gmez, 26
# Rost'om Omeris dze Abashidze, 29
# Nunu Dzhansuhivna Abashydze (-Myslaieva), 25
# Rodrigo Abasolo, 21
# Tamila Rashidovna Abasova, 21
# Tamila Rashidovna Abasova, 21
# Emanuele Abate, 27
# Ignazio Abate, 21
# Jol Marc Abati, 34
# Jol Marc Abati, 38
# Ral Abatte, 38
# Georgia Abatzidou, 35
# Carlos Rodolfo Abaunza Balladares, 18
# Carlos Alberto Abaunza, 16
# Hctor Abaunza, 30
# Hctor Abaunza, 30
# Hctor Abaunza, 30
# Pter Abay, 30
# Oszkr Abay-Nemes, 22
# Oszkr Abay-Nemes, 22
# Adeyemi Abayomi, 25
# Sayed Fahmy Abaza, NA
# Sayed Fahmy Abaza, NA
# Silvano Abba, 25
# Gana Abba Kimet, 26
# Ilyas Abbadi, 19
# Ilyas Abbadi, 23
# Agostino Abbagnale, 22
# Agostino Abbagnale, 29
# Agostino Abbagnale, 34
# Carmine Abbagnale, 22
# Carmine Abbagnale, 26
# Carmine Abbagnale, 30
# Carmine Abbagnale, 34
# Giuseppe Abbagnale, 20
# Giuseppe Abbagnale, 25
# Giuseppe Abbagnale, 29
# Giuseppe Abbagnale, 33
# Abdul Latif Al-Sayed Abbas Youssef Hashem, 23
# Abdul Latif Al-Sayed Abbas Youssef Hashem, 23
# Abdul Latif Al-Sayed Abbas Youssef Hashem, 27
# Abubakar Abbas Abbas, 20
# Aqarab Abbas, 22
# Aziz Abbas, 21
# Bassim Abbas Kati Al-Ogaili, 22
# Essa Abbas Faleh Hashem, 20
# Ghulam Abbas, 24
# Hosni Mohamed Abbas, 28
# Hosni Mohamed Abbas, 32
# Maher Abbas, 22
# Maher Abbas, 22
# Mahmoud Abbas, 22
# Mohamed Fakhry Rifaat Abbas, 19
# Mohammed Abbas Sabih, 26
# Muhammad Abbas, 23
# Nader Sufyan Abbas, 28
# Sohail Abbas, 25
# Sohail Abbas, 29
# Sohail Abbas, 37
# Youssef Mohamed Abbas, 31
# Zulkifli Abbas, 28
# Forough Abbasi, 20
# Shakeel Abbasi, 20
# Shakeel Abbasi, 24
# Shakeel Abbasi, 28
# Soulmaz Abbasi Azad, 28
# Ruslan Abbasov, 22
# Tural Abbasov, 18
# Tran Abbasova, 33
# Simona Abbate, 28
# Franz Abb, NA
# Christian Abbiati, 23
# Lois Abbingh, 23
# Alessandro Abbio, 29
# Giordano Giulio Abbondati, 15
# Giordano Giulio Abbondati, 19
# Salwan Jasim Abbood Abbood, 24
# George "Ioannis" Abbot, NA
# William "Bill" Abbott Jr., 42
# William "Bill" Abbott Jr., 46
# Clare Abbott, 30
# Clare Abbott, 30
# David "Dave" Abbott, 26
# Desmond "Des" Abbott, 21
# Geoffrey Grant Abbott, 23
# Jeremy Abbott, 24
# Jeremy Abbott, 28
# Jeremy Abbott, 28
# Jeremy Abbott, 19
# Joanne Abbott, 41
# Kathryn "Katie" Abbott, 21
# Mara Katherine Abbott, 30
# Margaret Ives Abbott (-Dunne), 23
# Mary Perkins Ives Abbott (Perkins-), 42
# Matt Abbott, 34
# Monica Cecilia Abbott, 23
# Khadija Abbouda, 40
# Mohamed Ibrahim Abd El-Fatah Mohamed, 22
# Mohamed Ibrahim Abd El-Fatah Mohamed, 26
# Mohamed Ibrahim Abd El-Fatah Mohamed, 34
# Mahmoud Abd El-Kader, 23
# Mohamed Ibrahim Abd El-Salam, 22
# Mohamed Ibrahim Abd El-Salam, 26
# Noha Abd Rabo, 21
# Reem Wa'il Abdalazem Abdalazem El-Bossaty, 15
# Reem Wa'il Abdalazem Abdalazem El-Bossaty, 15
# Reem Wa'il Abdalazem Abdalazem El-Bossaty, 19
# Ali Abdalla Afringi, 25
# Hossam Abdalla, 28
# Hosam Abdallah, 25
# Hosam Abdallah, 29
# Ismail Abdallah, NA
# Ismail Abdallah, NA
# Ismail Abdallah, NA
# Ismail Abdallah, NA
# Ismail Abdallah, NA
# Ismail Abdallah, NA
# Ismail Abdallah, NA
# Ismail Abdallah, NA
# Maged Abdallah, 22
# Nia Nicole Abdallah, 20
# Omari Abdallah, 21
# Omari Abdallah, 29
# Ould Lamine Abdallah, NA
# Younis Abdallah Rabee, 23
# Raida Abdallah Bader, 19
# Maha Abdalsalam Gouda, 18
# Mahmoud Abdel Aziz, 25
# Mohamed Abdel Ellah, 32
# Mohamed Abdel Fatah, NA
# Ali Mohamed Badawi Abdel Fattah Badawi, 19
# Abdelgani Hassan Abdel Fattah, 31
# Mahmoud Atter Abdel Fattah, NA
# Mohamed Abdel Fattah, 23
# Sayed Abdel Gadir, 23
# Sayed Abdel Gadir, 32
# Ibrahim Saad Abdel Galil, NA
# Ibrahim Saad Abdel Galil, NA
# Heba Abdel Gawad, 18
# Heba Abdel Gawad, 22
# Sara Abdel Gawad, 18
# Gamal Amin Abdel Ghani, 29
# Abdel Sattar Abdel Hadj, NA
# Ragy Abdel Hady, 30
# Osman Abdel Hafeez, 31
# Osman Abdel Hafeez, 31
# Osman Abdel Hafeez, 31
# Osman Abdel Hafeez, 35
# Osman Abdel Hafeez, 35
# Mohamed Abdel Hafiz, NA
# Moustafa Ali Abdel Halim, 32
# Mohamed Abdel Hamed, 24
# Hwad Ibrahim Abdel Hamid Lumomba, NA
# Ibrahim Abdel Hamid, NA
# Tamer Mohamed Abdel Hamid, 20
# Ahmed El-Sayed Abdel Hamid Mobarak, 25
# Dorri Abdel Kader Said, 21
# Dorri Abdel Kader Said, 21
# Dorri Abdel Kader Said, 21
# Dorri Abdel Kader Said, 25
# Dorri Abdel Kader Said, 25
# Dorri Abdel Kader Said, 33
# Moustafa Mounib Abdel Kader, NA
# Mohamed Ali Abdel Kerim, 24
# Mohamed Ali Abdel Kerim, 32
# Mohamed Abdel Khaled, 24
# Abdel Latif Abdel Latif, 28
# Walid Abdel Maksoud, 29
# Amir Abdel Meguid, 23
# Amir Abdel Meguid, 27
# Mohamed Abdel Mohamed, 24
# Karim Abdel Mohsen, 25
# Awad Abdel Nabi Awad, 19
# Awad Abdel Nabi Awad, 23
# Ahmed Abdel Naeim, 23
# Ahmed Abdel Naeim, 31
# Moustafa Abdel Naser, 21
# Ali Abdel Radi, 24
# Amin Abdel Rahman, 18
# Amin Abdel Rahman, 22
# Mohamed Fathallah Abdel Rahman, 21
# Mohamed Fathallah Abdel Rahman, 33
# Mohamed Fathallah Abdel Rahman, 33
# Mohamed Fathallah Abdel Rahman, 37
# Mohamed Fathallah Abdel Rahman, 37
# Mohamed Fathallah Abdel Rahman, 37
# Mohamed Fathallah Abdel Rahman, 37
# Fathi Ali Abdel Rahman, 20
# Ibrahim Abdel Rahman, NA
# Khaled Abdel Rahman, 27
# Sameh Abdel Rahman, 16
# Sameh Abdel Rahman, 21
# Sameh Abdel Rahman, 21
# Yasser Abdel Rahman Sakr, 30
# Samy Abdel Razek, 28
# Samy Abdel Razek, 36
# Samy Abdel Razek, 36
# Mohamed Youssef Abdel Razik, 21
# Ibrahim Ahmed Abdel Rehim, 21
# Kamal Abdel Rehim, 26
# Reskalla Mohamed Abdel Rehim, 22
# Ahmed Ali Abdel Samad, 27
# Ali Abdel Sami, 28
# Mohamed Abdel Sami, NA
# Sameh Abdel Waress Muhammad, 24
# Mohamed Said Abdel Wehab, 22
# Mahmoud Abdel-Aal, 19
# Mahmoud Abdel-Aal, 19
# Mahmoud Abdel-Aal, 19
# Mahmoud Abdel-Aal, 19
# Mahmoud Abdel-Aal, 19
# Mahmoud Abdel-Aal, 19
# Mahmoud Abdel-Aal, 19
# Mahmoud Abdel-Aal, 19
# Mohamed Abdel-El, NA
# Shaimaa Abdel-Latif-Hashad, 23
# Shaimaa Abdel-Latif-Hashad, 27
# Shaimaa Abdel-Latif-Hashad, 35
# Sanad Bushara Abdel-Nadif, NA
# Ahmed Abdelaal, 27
# Mahmoud Abdelaal, 24
# Mohamed Ali Abdelaal, 26
# Moustafa Abdelal, NA
# Moustafa Abdelal, NA
# Moustafa Abdelal, NA
# Moustafa Abdelal, NA
# Moustafa Abdelal, NA
# Moustafa Abdelal, NA
# Moustafa Abdelal, NA
# Moustafa Abdelal, NA
# Mahmod Abdelaly, 41
# Ibrahim Ramadan Ibrahim Abdelbaki, 24
# Ibrahim Ramadan Ibrahim Abdelbaki, 28
# Aziza Abdelfattah, 17
# Abdalla Abdelgadir El-Sheikh, 21
# Magdi Abdelghani Sayed Ahmed, 25
# Ragab Abdelhay Saad Abdelrazek Abdallah, 21
# Ragab Abdelhay Saad Abdelrazek Abdallah, 25
# Ben Ahmed Abdelkrim, 20
# Mohamed Abdellah, 36
# Mohamed Abdellah, 40
# Ayoub Abdellaoui, 23
# Leila Abdelmoez, 19
# Sayed Abdelmonem Sayed Hamed, 23
# Ahmed Abdelrahman, 20
# Ihab Abdelrahman El-Sayed Abdelrahman, 23
# Raouf Abdelraouf, 22
# Raouf Abdelraouf, 22
# Raouf Abdelraouf, 22
# Raouf Abdelraouf, 22
# Raouf Abdelraouf, 22
# Abouelfetoh Abdelrazek, 21
# Mamdouh Abdelrehim, 26
# El-Hachemi Abdenouz, 24
# Rda Abdenouz, 19
# Rda Abdenouz, 23
# Mouni Abderrahim, 22
# Mouni Abderrahim, 26
# Saeid Morad Abdevali, 22
# Saeid Morad Abdevali, 26
# Bashir Abdi, 27
# Bashir Abdi, 27
# Youcef Abdi, 30
# Youcef Abdi, 34
# Jamal Abdi Hassan Abdullah, 19
# Jamal Abdi Hassan Abdullah, 23
# Talal Omar Abdillahi, 21
# Talal Omar Abdillahi, 25
# Mahmoud Ahmed Abdin, 21
# Mahmoud Ahmed Abdin, 21
# Mahmoud Ahmed Abdin, 29
# Mahmoud Ahmed Abdin, 29
# Mahmoud Ahmed Abdin, 29
# Mahmoud Ahmed Abdin, 29
# Mahmoud Ahmed Abdin, 41
# Abdihakim "Abdi" Abdirahman, 23
# Abdihakim "Abdi" Abdirahman, 27
# Abdihakim "Abdi" Abdirahman, 31
# Abdihakim "Abdi" Abdirahman, 35
# Ali Abdo, 19
# Ali Abdo, 23
# Ali Abdo, 27
# Hamza Abdo, 17
# Reema Abdo, 21
# Reema Abdo, 21
# Reema Abdo, 21
# Ahmed Abdo Mustafa, NA
# Nasrollah Abdollahi, 24
# Yhyacinthe Mewoli Abdon, 26
# Hassane Abdou, 23
# Justin Abdou, 29
# Moustafa Ahmed Ismail Abdou Ali Arfah, 31
# Raouf Abdou, 22
# Mohamed Abdou El-Souad, 19
# Mohamed Abdou El-Souad, 19
# Mohamed Abdou El-Souad, 23
# Mohamed Abdou El-Souad, 23
# Brahim Daoud Abdoulaye, 25
# Fawziya Abdoulkarim, 27
# Alaa El-Din Abdoun, 23
# Ibrahim Abdrabbou, 27
# Berik Abdrakhmanov, 30
# Maizurah Abdul Rahim, 17
# Mehdi Fahim Abdul Al-Sada, 24
# Bashir Abdullah Abdul Aziz, 22
# Chairil Anwar Abdul Aziz, 24
# Chairil Anwar Abdul Aziz, 28
# Shaimaa Abdul Aziz, 19
# Shaimaa Abdul Aziz, 19
# Shaimaa Abdul Aziz, 27
# Mohamed Abdul Hadj, 25
# Jefri Kiko Bolkiah Abdul Hakeem, 23
# Jefri Kiko Bolkiah Abdul Hakeem, 27
# Mohamed Abdul Hamid, 19
# S. Abdul Hamid, NA
# S. Abdul Hamid, NA
# Hadi Abdul Jabbar, 30
# Hadi Abdul Jabbar, 34
# Mohamed Abed Abdul Jawad, 22
# Anouar Abdul Kader, 27
# Talal Hassoun Abdul Kader, NA
# Abdul Aziz Hassan Al-Hadba Abdul Karim Abdul Kareem, 23
# Abdul Aziz Hassan Al-Hadba Abdul Karim Abdul Kareem, 23
# Taha Abdul Karim, 20
# Masoud Abdul Khamis Al-Rahman, 17
# Abdul Haji Abdul Latheef, 17
# Fatima Abdul Majeed Hameed Al-Kirashi, 14
# Majed Ahmed Abdul Mohamed, 26
# Firouz Abdul Mohammadian, 34
# Hussam Abdul Rahman, 30
# Mohamed Ghulom Abdul Rahman, NA
# Suleman Abdul Rahman, 29
# Zambrose Abdul Rahman, 24
# Lala Abdul Rashid, 38
# Muhammad Abdul Rashid, 23
# Dana Abdul Razak (Hussain-), 22
# Dana Abdul Razak (Hussain-), 26
# A. Abdul Razzak, NA
# A. Abdul Razzak, NA
# Mohamed Abdul Razzak, NA
# Muhammad Abdul Razzaq, NA
# Hazim Abdul Ridha, NA
# Rauf Abdul Seoud, 21
# Rauf Abdul Seoud, 33
# Samir Ahmed Abdul Shakour, 24
# Nabil Abdul Tahlak, 39
# Fahmi Ahmed Abdul Wahab Al-Tahri, 23
# Mohamed Abdul Wahab Al-Salah, 21
# Mohamed Abdul Wahab Al-Salah, 21
# Qazi Abdul Waheed, 30
# Patmawati Abdul Wahid, 32
# Haidar Abdul-Amir Hassan, 21
# Haidar Abdul-Razzaq Hassan, 22
# Lawal Kolawole "Kola" Abdulai, 21
# Lawal Kolawole "Kola" Abdulai, 21
# Lawal Kolawole "Kola" Abdulai, 25
# Lawal Kolawole "Kola" Abdulai, 25
# Rukayatu "Ruky" Abdulai, 22
# Mona Ahmad Abdulaziz Hassanein, 26
# Zagalav Abdulbekovich Abdulbekov, 26
# Roosevelt M. Abdulgafur, 24
# Roosevelt M. Abdulgafur, 24
# Roosevelt M. Abdulgafur, 24
# Roosevelt M. Abdulgafur, 24
# Roosevelt M. Abdulgafur, 24
# Ahmed Abdulkareem Ahmed, 20
# Gamal Ahmed Abdulla, 28
# Mohamed Sayed Abdulla, 18
# Ahmad Hassan Abdullah, 27
# Ahmed Ghanim Abdullah, 20
# Aquil Hashim Abdullah (Shumate-), 31
# Atallah Abdullah, 32
# Magdy Ahmed Abdullah, 25
# Mohamed Abdullah, NA
# Mohamed Abdullah, NA
# Mohamed Abdullah, NA
# Mohamed Abdullah, NA
# Mohamed Abdullah, NA
# Mohamed Abdullah, NA
# Mohamed Samy Abdullah, NA
# Mohamed Abdullah, NA
# Osama Abdullah, 21
# Tewfik Abdullah, 23
# Wan Azlan Abdullah, 21
# Wan Azlan Abdullah, 21
# Wan Azlan Abdullah, 21
# Wan Azlan Abdullah, 25
# Zarinah Abdullah, 21
# Zarinah Abdullah, 25
# Abdel Wahab Abdullah Salih, NA
# Abdel Wahab Abdullah Salih, NA
# Abubakar Sadiq Abdullahi, 28
# Abdulqdir Abdullayev, 28
# Arif Yadulla Abdullayev, 27
# Arif Yadulla Abdullayev, 32
# Mukhammad Kadyr Abdullayev, 22
# Mukhammad Kadyr Abdullayev, 26
# Muminzhon Abdullayev, 22
# Muminzhon Abdullayev, 26
# Namiq Yadulla Abdullayev, 25
# Namiq Yadulla Abdullayev, 29
# Namiq Yadulla Abdullayev, 33
# Laye Abdullayeva, 21
# lqar Abdulov, 27
# Abdullah Abdulrahman Zeyab, 16
# Abir Abdulrahman Khalil Mahmoud Khalil, 16
# Abir Abdulrahman Khalil Mahmoud Khalil, 20
# Amer Abdulrahman Abdallah Hussain Al-Hammadi, 23
# Omar Abdulrahman Ahmad Al-Raaqi Al-Amoudi, 20
# Shaza Yahia Nazih Abdulrahman El-Sayed, 15
# Shaza Yahia Nazih Abdulrahman El-Sayed, 19
# Shaza Yahia Nazih Abdulrahman El-Sayed, 19
# Najim Abdulrazak Al-Enazy, 18
# Zeyad Abdulrazak Al-Khudhur Al-Enazy, 19
# Zeyad Abdulrazak Al-Khudhur Al-Enazy, 23
# Waheed Abdulridha Waheed Karaawi, 33
# Mohamed Abdultwab Ibrahim Abd El-Baki, 21
# Mohamed Abdultwab Ibrahim Abd El-Baki, 25
# Julius Shareef Abdur-Rahim, 23
# Sherzod Abdurahmonov, 22
# Rasul Abduraim, 19
# Rasul Abduraim, 23
# Bekzod Makhamadzhonovich Abdurakhmonov, 26
# Mukhamadmurod Abdurakhmonov, 29
# Adlan Aliyevich Abdurashidov, 26
# Yusup Abdusalomov, 26
# Yusup Abdusalomov, 30
# Yusup Abdusalomov, 34
# Fawzi Abdussalam, NA
# Andrey Khakimovich Abduvaliyev, 26
# Andrey Khakimovich Abduvaliyev, 34
# Dzhamolidin Mirgarifanovich Abduzhaparov, 24
# Dzhamolidin Mirgarifanovich Abduzhaparov, 32
# Aybek Abdymomunov, 18
# Isao Ko Abe, 24
# Kazumi Abe, 24
# Kazumi Abe, 24
# Kazumi Abe, 28
# Kazumi Abe, 28
# Kazuo Abe, 25
# Kinya Abe, 23
# Kiyoshi Abe, 25
# Masashi Abe, 22
# Masashi Abe, 22
# Masashi Abe, 26
# Masashi Abe, 28
# Masashi Abe, 28
# Naoki Abe, 23
# Naoki Abe, 23
# Osamu Abe, 22
# Shigeaki Abe, 24
# Shigeaki Abe, 28
# Shinnosuke Abe, 21
# Shinnosuke Abe, 29
# Sanshiro "Sonny" Abe, 26
# Tadashi Abe, 21
# Tadashi Abe, 25
# Tadashi Abe, 29
# Tadatoshi Abe, 28
# Wakako Abe, 18
# Yoshiyuki Abe, 31
# Yuki Abe, 22
# Angelik Abebame, NA
# Addis Abebe, 21
# Addis Abebe, 21
# Biruk Abebe, 22
# Biruk Abebe, 22
# Benaissa Abed, 23
# Soha Abed Elaal, 35
# Mojtaba Abedini Shormasti, 27
# Mojtaba Abedini Shormasti, 31
# Thophile Abega Mbida, 30
# Max "Xam" Abegglen, 22
# Max "Xam" Abegglen, 26
# Alexandre Abeid, 22
# Alexandre Abeid, 26
# Sonia Abejn Esteban, 19
# Abel Carlos da Silva Braga, 19
# Adolf Gaston Abel, 45
# Adolf Gaston Abel, 45
# Brooke Abel, 20
# Clarence John Abel, 23
# George Gordon Abel, 35
# Gnther Abel, 19
# Gnther Abel, 23
# Irene Abel, 19
# Irene Abel, 19
# Irene Abel, 19
# Irene Abel, 19
# Irene Abel, 19
# Irene Abel, 19
# Jennifer Abel, 16
# Jennifer Abel, 20
# Jennifer Abel, 20
# Jennifer Abel, 24
# Jennifer Abel, 24
# Katja Abel, 25
# Katja Abel, 25
# Katja Abel, 25
# Katja Abel, 25
# Katja Abel, 25
# Mara Abel Diguez, 25
# Mara Abel Diguez, 29
# Roger Abel, 24
# Roger Abel, 36
# Roger Abel, 36
# Roger Abel, 48
# Roger Abel, 52
# Roger Abel, 52
# Egil Sten Abel, 20
# Yaritza Abel Rojas, 28
# Abelardo Fernndez Antua, 22
# Arthur Abele, 22
# Arthur Abele, 30
# Ruth Abeles, 18
# Ruth Abeles, 18
# Ruth Abeles, 18
# Ruth Abeles, 18
# Ruth Abeles, 18
# Louis Grenville "Lou" Abell, 15
# Louis Grenville "Lou" Abell, 19
# Jos Javier Abella Fanjul, 22
# Ramn Neptuno Abella Caside, 26
# Ral Daniel Abella, 26
# Ral Daniel Abella, 26
# Ral Daniel Abella, 26
# Alfonso Abelln Lpez, 37
# Juan Luis Abelln Pallahi, 19
# Edwige Marie Abna Fouda, 23
# Gezahgne Abera, 22
# Tesfaye Abera Dibaba, 24
# Hugo Ral Aberastegui, 27
# Hugo Ral Aberastegui, 30
# Hugo Ral Aberastegui, 34
# Arvid berg, 26
# Bjrn Olof Conny berg, 23
# Nils Georg berg, 19
# Nils Georg berg, 19
# Sara Helena berg, 17
# Karl Konrad berg, 22
# Majken berg, 30
# Olof Viktor "Olle" berg, 27
# Mohamed Aberhoune, 23
# Julianne "Anne" Abernathy, 34
# Julianne "Anne" Abernathy, 38
# Julianne "Anne" Abernathy, 40
# Julianne "Anne" Abernathy, 44
# Julianne "Anne" Abernathy, 48
# Michael Brent Abernathy, 22
# Moira Abernethy (-Ford), 17
# Moira Abernethy (-Ford), 17
# Salim Abes, 25
# Edme Abetel (-Barr), 29
# Pasqualino Abeti, 24
# Elvan Abeylegesse, 21
# Elvan Abeylegesse, 21
# Elvan Abeylegesse, 25
# Elvan Abeylegesse, 25
# Ruwani Abeymanne, 30
# Ruwani Abeymanne, 30
# Matthew Duncan Abeysinghe, 20
# Narek Abgaryan, 24
# Koutoua Francis Abia, 26
# Koutoua Francis Abia, 30
# Koutoua Francis Abia, 42
# Koutoua Francis Abia, 42
# Pablo Abin Vicen, 23
# Pablo Abin Vicen, 27
# Pablo Abin Vicen, 31
# David Abibssira, 21
# Silke Abicht, 19
# Haithem Abid, 22
# Younis Abid Sadkhan, 18
# Jaiye Abidoye, 30
# Jaiye Abidoye, 30
# Sagat Abikeyeva, 27
# Mitsuhiro Abiko, 19
# Tomomi Abiko, 24
# Catherine "Kate" Abilla Awino, 27
# Ismail Abilov (-Nizamolu), 25
# Ismail Abilov (-Nizamolu), 29
# Camille Anne Franoise Abily, 27
# Camille Anne Franoise Abily, 31
# Endurance Abinuwa, 24
# Bode Abiodun, 35
# Firmin Abissi, 28
# Firmin Abissi, 32
# Sarah Abitbol, 22
# Inga Eduardovna Abitova, 26
# Ceyhun Abiyev, 29
# Diana Monteiro Abla, 21
# Enver Nazymovych Ablaiev, 22
# Enver Nazymovych Ablaiev, 26
# Enver Nazymovych Ablaiev, 30
# Leslie Ablett, 24
# Leslie Ablett, 32
# Edgar Allen "Ed" Ablowich, 19
# Denis Mikhaylovich Ablyazin, 19
# Denis Mikhaylovich Ablyazin, 19
# Denis Mikhaylovich Ablyazin, 19
# Denis Mikhaylovich Ablyazin, 19
# Denis Mikhaylovich Ablyazin, 19
# Denis Mikhaylovich Ablyazin, 19
# Denis Mikhaylovich Ablyazin, 24
# Denis Mikhaylovich Ablyazin, 24
# Denis Mikhaylovich Ablyazin, 24
# Denis Mikhaylovich Ablyazin, 24
# Karin Abma, 24
# Thorine Christelle Aboa Mbeza, 23
# Felix Ahmed Aboagye, 20
# Bukola Dammy Abogunloko, 17
# Viktor Andreyevich Aboimov, 22
# Viktor Andreyevich Aboimov, 22
# Viktor Andreyevich Aboimov, 22
# Viktor Andreyevich Aboimov, 22
# Mohamed Aboker, 26
# Mohamed Aboker, 26
# Ilze bola, 19
# Agnese boltia, 17
# Agnese boltia, 17
# Agnese boltia, 17
# Abdul Razzak Aboobakur, 25
# Matthew "Matt" Abood, 30
# Matthew "Matt" Abood, 30
# Piroska Abos Gvorgyzakab, 25
# Piroska Abos Gvorgyzakab, 25
# Piroska Abos Gvorgyzakab, 25
# Jean-Pierre Abossolo-Ze, 27
# Jean-Pierre Abossolo-Ze, 27
# Abdelhalim Muhammad Abou, 27
# Tarek Abou Al Dahab, 28
# Tarek Abou Al Dahab, 28
# Tarek Abou Al Dahab, 28
# Tarek Abou Al Dahab, 28
# Tarek Abou Al Dahab, 32
# Tarek Abou Al Dahab, 32
# Bachir Hani Abou Assi, 24
# Ashraf Abou El-Hassan, 25
# Ashraf Abou El-Hassan, 33
# Ashraf Abou El-Hassan, 41
# Galal El-Din Abdel Meguid Abou El-Kheir, 24
# Magdy Abou El-Magd, 27
# Essameldin Abou El-Nein, 29
# Abdel Khlik Abou El-Yazi, 26
# Mohamed Moustafa Abou Elea, 20
# Mahmoud Abou Elelaa, 30
# Mohammed Tawfiq Abou Habaga, 27
# Zaid Abou Hamed, 30
# Youssef Kamel Mohamed Abou Ouf, 24
# Youssef Kamel Mohamed Abou Ouf, 28
# Gaber Mooti Abou Zeid, 22
# Gaber Mooti Abou Zeid, 30
# Taher Abou Zeid Sayid Amer, 22
# Ahmed Farid Abou-Shadi, 38
# Ahmed Farid Abou-Shadi, 38
# Ahmed Farid Abou-Shadi, 42
# Ahmed Farid Abou-Shadi, 42
# Abdel Fattah Abou-Shanab, 24
# Abdel Fattah Abou-Shanab, 28
# Sadoon Mohamed Aboub, 21
# Zakaria Aboub, 20
# Inni Aboubacar, NA
# Ibrahim Mohamedin Aboubaker, 21
# Ibrahim Mohamedin Aboubaker, 25
# Ahmed Ghmin Aboud, 22
# Fathi Khalifa Aboud, 23
# Kamel Aboud, 22
# Marwan Suhail Aboud, NA
# Rabah Aboud, 31
# Mamdouh Taha Al-Husseini Abouebaid, 28
# Alaaeldin Ahmad El-Sayyid Abouelkassem, 21
# Alaaeldin Ahmad El-Sayyid Abouelkassem, 21
# Alaaeldin Ahmad El-Sayyid Abouelkassem, 25
# Alaaeldin Ahmad El-Sayyid Abouelkassem, 25
# Haysam Farouk Abouelw, 21
# Waguih Rauf Aboul Seoud, 22
# El-Sayed Aboumedan, 26
# Dany Abounaoum, 22
# Dany Abounaoum, 22
# Sdonoud Janvier Abouta, 23
# Mohamed Mohamed Mohamed Aboutrika, 33
# Ahmad Shah Abouwi, NA
# Adeola Aboyade-Cole, 22
# Cheryl Abplanalp, 24
# Alexander "Alex" Abraham (Steglitz), 25
# Andrei Abraham, 19
# Andrei Abraham, 19
# Andrei Abraham, 19
# Andrei Abraham, 19
# Andrei Abraham, 19
# Andrei Abraham, 19
# Andrei Abraham, 19
# Andrei Abraham, 19
# Attila brahm, 21
# Attila brahm, 21
# Attila brahm, 25
# Bernhard Abraham, NA
# Gary Abraham, 17
# Gary Abraham, 17
# Gary Abraham, 21
# Gary Abraham, 21
# Gary Abraham, 21
# Melita Isidora Abraham Schssler, 19
# Tadesse Abraham, 33
# Shiny Kurisingal Abraham-Wilson, 19
# Shiny Kurisingal Abraham-Wilson, 19
# Shiny Kurisingal Abraham-Wilson, 23
# Shiny Kurisingal Abraham-Wilson, 23
# Shiny Kurisingal Abraham-Wilson, 27
# Shiny Kurisingal Abraham-Wilson, 31
# Mariola Teresa Abrahamczyk (-Fronckowiak), 21
# Ara Abrahamian, 25
# Ara Abrahamian, 29
# Ara Abrahamian, 33
# Stphan Abrahamian Gonzalez, 22
# Clyde Abrahams, 29
# Glen Abrahams Martnez, 22
# Glen Abrahams Martnez, 22
# Guy A. Abrahams, 23
# Guy A. Abrahams, 23
# Harold Maurice Abrahams, 20
# Harold Maurice Abrahams, 20
# Harold Maurice Abrahams, 20
# Harold Maurice Abrahams, 20
# Harold Maurice Abrahams, 24
# Harold Maurice Abrahams, 24
# Harold Maurice Abrahams, 24
# Sidney Solomon Abrahams, 21
# Sidney Solomon Abrahams, 21
# Sidney Solomon Abrahams, 27
# Isak Abrahamsen, 21
# Knut Leo Abrahamsen, 25
# Trond Sevg Abrahamsen, 19
# Trond Sevg Abrahamsen, 23
# Donald Robert Abrahamson, Jr., 26
# Richard Neal Abrahamson, 24
# Richard Neal Abrahamson, 28
# Kurt Christer Abrahamsson (-Abris), 24
# Erik Adolf Efraim Abrahamsson, 22
# Karl Gran Abrahamsson, 28
# Karl Gran Abrahamsson, 28
# Karl Gran Abrahamsson, 28
# Karl Gran Abrahamsson, 33
# Karl Gran Abrahamsson, 33
# Karl Gustaf Emanuel Abrahamsson, 31
# Ulf Thommy Abrahamsson, 24
# Fletcher Abram, Jr., 21
# Iason Abramashvili, 17
# Iason Abramashvili, 17
# Iason Abramashvili, 21
# Iason Abramashvili, 21
# Iason Abramashvili, 25
# Iason Abramashvili, 25
# Yelena Vasilyevna Abramchuk (Kopets-), 28
# Oleksandr Volodymyrovych Abramenko, 17
# Oleksandr Volodymyrovych Abramenko, 21
# Oleksandr Volodymyrovych Abramenko, 25
# Yevgeny Sergeyevich Abramenko, 22
# Yevgeny Sergeyevich Abramenko, 22
# Yevgeny Sergeyevich Abramenko, 22
# Yevgeny Sergeyevich Abramenko, 22
# Yevgeny Sergeyevich Abramenko, 26
# Yevgeny Sergeyevich Abramenko, 26
# Yevgeny Sergeyevich Abramenko, 26
# Yevgeny Sergeyevich Abramenko, 26
# Yevgeny Sergeyevich Abramenko, 26
# Lahcen Abrami, 22
# Ek'aterina Abramia, 16
# Jernej Abrami, 31
# Levan Abramishvili, 23
# Levan Abramishvili, 27
# Andrey Vasilyevich Abramov, 24
# Andrey Viktorovich Abramov, 24
# Andrey Viktorovich Abramov, 24
# Nikolay Kuzmich Abramov, 30
# Pavel Sergeyevich Abramov, 25
# Sergey Mikhaylovich Abramov, 34
# Valery Aleksandrovich Abramov, 23
# Inna Vladimirovna Abramova, 21
# Inna Vladimirovna Abramova, 21
# Nelli Mikhaylovna Abramova, 24
# Yekaterina Konstantinovna Abramova, 23
# Yekaterina Konstantinovna Abramova, 23
# Yekaterina Konstantinovna Abramova, 23
# Yekaterina Konstantinovna Abramova, 27
# Alen Abramovi, 29
# Alen Abramovi, 29
# Dmitry Vladimirovich Abramovich, 27
# Dmitry Vladimirovich Abramovich, 27
# Aliyah Abrams, 19
# Colin Winston Abrams, 32
# John Charles Abrams, 22
# John Charles Abrams, 25
# Benik Abramyan, 31
# Antnio da Cunha Meneses Martins Abrantes, 20
# Antnio da Cunha Meneses Martins Abrantes, 20
# Antnio da Cunha Meneses Martins Abrantes, 24
# Antnio da Cunha Meneses Martins Abrantes, 28
# Arnaldo Lus Isaas Abrantes, 21
# Arnaldo Lus Isaas Abrantes, 25
# Arnaldo Joaquim Castro Abrantes, 26
# David Abrard, 19
# Tsvetelina Abrasheva, 16
# Amir Abrashi, 22
# Thomas Abratis, 26
# Thomas Abratis, 26
# Pawe Abratkiewicz, 21
# Pawe Abratkiewicz, 21
#  Average age in years for all olympians =  23.895895895895897

# %% [markdown]
# ## Summary
# - Files are essential for saving and retrieving data.
# - Different types of files and access methods.
# - Using loops for processing files.
# - Handling exceptions to make programs more robust.
